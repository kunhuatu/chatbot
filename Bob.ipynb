# %%
from imp import reload
import chatbot; reload(chatbot)
from chatbot import ChatBot

# %%
Bob = ChatBot('Bob')

# %%
Bob.train()
# Out:
# Start training...
# Epoch: 1
# 	step: 100, train_loss: 3.0457, time_spent: 115.53s
# 	step: 200, train_loss: 2.8659, time_spent: 113.88s
# 	step: 300, train_loss: 2.7302, time_spent: 118.21s
# 	step: 400, train_loss: 2.6366, time_spent: 113.91s
# 	step: 500, train_loss: 2.5785, time_spent: 117.26s
# 	step: 600, train_loss: 2.5336, time_spent: 113.74s
# val_loss: 2.2671
# Epoch: 2
# 	step: 100, train_loss: 2.2640, time_spent: 113.87s
# 	step: 200, train_loss: 2.2682, time_spent: 113.82s
# 	step: 300, train_loss: 2.2598, time_spent: 117.25s
# 	step: 400, train_loss: 2.2639, time_spent: 113.84s
# 	step: 500, train_loss: 2.2621, time_spent: 117.05s
# 	step: 600, train_loss: 2.2564, time_spent: 113.75s
# val_loss: 2.2237
# Epoch: 3
# 	step: 100, train_loss: 2.2164, time_spent: 113.88s
# 	step: 200, train_loss: 2.2261, time_spent: 113.66s
# 	step: 300, train_loss: 2.2273, time_spent: 117.07s
# 	step: 400, train_loss: 2.2254, time_spent: 113.76s
# ...

# %%
Bob.evaluate()
# Out:
# 2.0197816

# %%
Bob.start_chat()
# Out:
# user: Hello
# Bob:hello
# user: How are you
# Bob:i am fine
# user: Do you like Redsox
# Bob:no i do not
# user: How old are you
# Bob:i am fine
# user: where are you going?
# Bob:i am going to see you
# user: Do you snowboarding
# Bob:no i am not
# user: Let's take a look
# Bob:you are a
# user: when is the game today
# Bob:i will not be a
# user: How was the game today
# Bob:i do not know
# user: let's watch game of throne!
# Bob:you are a
# user: ...
# Bob:the
# user:
# Bob:the
